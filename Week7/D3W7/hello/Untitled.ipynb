# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt 
import datetime as dt

# %%
names = ["mpg", "cylinders", "displacement", "horsepower", "weight", "acceleration", "model_year", "origin", "car_name"]
df = pd.read_csv("auto-mpg (1).data ", header=None, names=names, delim_whitespace=True)

# %%
df.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model_year  \
# 0  18.0          8         307.0      130.0  3504.0          12.0          70
# 1  15.0          8         350.0      165.0  3693.0          11.5          70
# 2  18.0          8         318.0      150.0  3436.0          11.0          70
# 3  16.0          8         304.0      150.0  3433.0          12.0          70
# 4  17.0          8         302.0      140.0  3449.0          10.5          70
#
#    origin                   car_name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
def scatter_plot (df):
                  plt.scatter(df.displacement,df.acceleration)
                  plt.xlabel("displacement")
                  plt.ylabel("acceleration")
                  plt.title('scatter ')
                  plt.show()
                  
scatter_plot(df)

# %% [markdown]
# question 11

# %%
# compares the cylinders of all the cars from 1978 model_year and toyota company
def bar_plot (df):
 df = df[df.car_name.str.contains('toyota')]
 df = df[df.model_year == 78]
 plt.bar(df['car_name'],df['cylinders'])
bar_plot(df)

# %% [markdown]
# Create a function line_plot that takes the dataframe df and plots the change in weight throughout the years for the cars of toyota company.

# %%
def line_plot (df):
    df = df[df.car_name.str.contains('toyota')]
#   lines = df.plot.line(x='weight', y='model_year')
    plt.plot(df['weight'],df['model_year'] )
line_plot(df)
